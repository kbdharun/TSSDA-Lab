# %% [markdown]
# # Ex 1
#
# 13.01.24
#
# 1.) **Load a time-series data and peek at your time series data and query it by date-time. Also review summary statistics on time series data.**

# %%
from pandas import read_csv
series = read_csv('daily-total-female-births.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)

# %%
print(type(series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(series.head())
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: Births, dtype: int64

# %%
seriesp = read_csv('daily-total-female-births.csv', header=0, index_col=0)

# %%
print(seriesp.head(10))
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# 1959-01-06      29
# 1959-01-07      45
# 1959-01-08      43
# 1959-01-09      38
# 1959-01-10      27

# %%
print(seriesp.tail(5))
# Out:
#             Births
# Date
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50

# %%
print(seriesp.size)
# Out:
# 365

# %%
print(series['1959-01'])
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: Births, dtype: int64

# %%
print(series.describe)
# Out:
# <bound method NDFrame.describe of Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
#               ..
# 1959-12-27    37
# 1959-12-28    52
# 1959-12-29    48
# 1959-12-30    55
# 1959-12-31    50
# Name: Births, Length: 365, dtype: int64>

# %% [markdown]
# ## Plotting Data

# %%
from matplotlib import pyplot
pyplot.plot(series)
pyplot.show()
